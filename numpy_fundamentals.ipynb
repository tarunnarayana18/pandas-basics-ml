# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunnarayana18/pandas-basics-ml/blob/main/numpy_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

student = {
    "Name": ["Tarun", "Rahul", "Priya"],
    "Age": [21, 22, 20],
    "Marks": [85, 90, 88]
}

df = pd.DataFrame(student)

print(df)
print(df.head())
print(df.describe())
# Out:
#     Name  Age  Marks
# 0  Tarun   21     85
# 1  Rahul   22     90
# 2  Priya   20     88
#     Name  Age  Marks
# 0  Tarun   21     85
# 1  Rahul   22     90
# 2  Priya   20     88
#         Age      Marks
# count   3.0   3.000000
# mean   21.0  87.666667
# std     1.0   2.516611
# min    20.0  85.000000
# 25%    20.5  86.500000
# 50%    21.0  88.000000
# 75%    21.5  89.000000
# max    22.0  90.000000
